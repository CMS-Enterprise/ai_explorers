# %%
import docx
import pandas
import spacy

def get_text_from_docx(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %%
# initialize language model
nlp = spacy.load("en_core_web_md")

# add pipeline (declared through entry_points in setup.py)
nlp.add_pipe("entityLinker", last=True)

def extract_entities(text, tagged_entities=None):        
    doc = nlp(text)
    ents = []

    # iterates over sentences and extracted linked entities
    for sent in doc.sents:
        for ent in sent._.linkedEntities:
            ents.append({
                'text': ent.get_span().text,
                'label': ent.label,
                'description': ent.description,
                'wikidata_id': ent.get_url().split('/')[-1],
                'superclasses': [{
                    'wikidata_id': ent.get_url().split('/')[-1], 
                    'label': ent.label
                } for ent in ent.get_super_entities()]
            })
    if tagged_entities is not None:
        ents = pandas.DataFrame(ents).join(tagged_entities, on='wikidata_id').dropna(subset=['seTag'])
        ents = ents.drop_duplicates(subset=['text', 'wikidata_id'])
    return ents

# %%
text = get_text_from_docx('RAD SOO for FY23 - Example SOO Only.docx')

# %%
print(text[:1000])
# Out:
# Simplified & Guided Security Planning for Rapid ATO
# Statement of Objective (SOO)
#
# Version 2.0
# 3/21/2022
#
#
#
#
#
#
#
#
#
#
#
#
# INFORMATION NOT RELEASABLE TO THE PUBLIC UNLESS AUTHORIZED BY LAW:
# This information has not been publicly disclosed and may be privileged and confidential. It is for internal government use only and must not be disseminated, distributed, or copied to persons not authorized to receive the information. Unauthorized disclosure may result in prosecution to the full extent of the law.
#
#
#
# Table of Contents
# Table of Contents	1
# Purpose	2
# Outputs	2
# Problem Statement	3
# Scope	3
# CMS Blueprint Digital Service (Blueprint)	3
# CMS Reusable Compliance Library	4
# Modern Web Content:	4
# Period and Place of Performance	4
# Required Skills	4
# Key Personnel	5
# Security Requirements	5
# Background	6
# Objectives	7
# Tasks	7
#       Task 1 CMS Reusable Compliance Library	7
# 1a. Build Artificial Intelligence pipelines and Services	7
# Candidate Components Identification Pipeline (also known as AI Pi

# %%
software_categories = pandas.read_csv('../ontology_building/wd_software_categories.csv')

# %%
software_categories['item'] = software_categories['item'].str.split('/').apply(lambda x: x[-1])

# %%
software_categories
# Out:
#            item                 itemLabel
# 0          Q341             free software
# 1          Q485            computer virus
# 2         Q6368               web browser
# 3         Q7889                video game
# 4         Q9135          operating system
# ..          ...                       ...
# 379  Q113723152                log viewer
# 380  Q113724486       screenshot software
# 381  Q114210323  Nintendo Switch emulator
# 382  Q114461696   cave surveying software
# 383  Q114873882              DVR software
#
# [384 rows x 2 columns]

# %%
entities = extract_entities(' '.join(text.split()))

# %%
entities = pandas.DataFrame(entities)

# %%
entities[entities['superclasses'].apply(
    lambda x: any([sup['wikidata_id'] in software_categories['item'].tolist() for sup in x]))]
# Out:
#                  text               label  \
# 55            Project   Microsoft Project
# 162             terms   terminal emulator
# 190             terms   terminal emulator
# 432        Kubernetes          Kubernetes
# 462        Processing          Processing
# 486        Confluence          Confluence
# 487              Jira                Jira
# 488             Slack               Slack
# 511   Project Manager  ProjectManager.com
# 852           Control             Control
# 854           Control             Control
# 868           Control             Control
# 922           Control             Control
# 1177             copy                COPY
# 1232          Project   Microsoft Project
# 1248       Confluence          Confluence
# 1249             Jira                Jira
# 1313       Processing          Processing
#
#                                             description wikidata_id  \
# 55                          Project management software      Q80336
# 162              program that emulates a video terminal    Q1071233
# 190              program that emulates a video terminal    Q1071233
# 432   software to manage containers on a server-clus...   Q22661306
# 462                                programming language    Q1053535
# 486                    A collaboration software program    Q1125400
# 487       issue-tracking product developed by Atlassian    Q1359246
# 488                               messaging application   Q17130715
# 511                         Project Management Software    Q7248945
# 852   2019 action-adventure video game developed by ...   Q54935655
# 854   2019 action-adventure video game developed by ...   Q54935655
# 868   2019 action-adventure video game developed by ...   Q54935655
# 922   2019 action-adventure video game developed by ...   Q54935655
# 1177  command of RT-11, RSX-11, OpenVMS, DOS, OS/2 a...    Q1394397
# 1232                        Project management software      Q80336
# 1248                   A collaboration software program    Q1125400
# 1249      issue-tracking product developed by Atlassian    Q1359246
# 1313                               programming language    Q1053535
#
#                                            superclasses
# 55    [{'wikidata_id': 'Q167035', 'label': 'project ...
# 162   [{'wikidata_id': 'Q17155032', 'label': 'softwa...
# 190   [{'wikidata_id': 'Q17155032', 'label': 'softwa...
# 432   [{'wikidata_id': 'Q341', 'label': 'free softwa...
# 462   [{'wikidata_id': 'Q9143', 'label': 'programmin...
# 486   [{'wikidata_id': 'Q474157', 'label': 'collabor...
# 487   [{'wikidata_id': 'Q167035', 'label': 'project ...
# 488   [{'wikidata_id': 'Q35127', 'label': 'website'}...
# 511   [{'wikidata_id': 'Q167035', 'label': 'project ...
# 852   [{'wikidata_id': 'Q7889', 'label': 'video game'}]
# 854   [{'wikidata_id': 'Q7889', 'label': 'video game'}]
# 868   [{'wikidata_id': 'Q7889', 'label': 'video game'}]
# 922   [{'wikidata_id': 'Q7889', 'label': 'video game'}]
# 1177  [{'wikidata_id': 'Q1079196', 'label': 'command...
# 1232  [{'wikidata_id': 'Q167035', 'label': 'project ...
# 1248  [{'wikidata_id': 'Q474157', 'label': 'collabor...
# 1249  [{'wikidata_id': 'Q167035', 'label': 'project ...
# 1313  [{'wikidata_id': 'Q9143', 'label': 'programmin...

# %%
entities[entities['text'].str.contains('AWS')]
# Out:
#      text                label  \
# 431   AWS  Amazon Web Services
# 1147  AWS  Amazon Web Services
#
#                                             description wikidata_id  \
# 431   subsidiary of Amazon that provides on-demand c...     Q456157
# 1147  subsidiary of Amazon that provides on-demand c...     Q456157
#
#                                            superclasses
# 431   [{'wikidata_id': 'Q658255', 'label': 'subsidia...
# 1147  [{'wikidata_id': 'Q658255', 'label': 'subsidia...
