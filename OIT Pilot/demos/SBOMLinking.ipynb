# %%
import requests
import pandas

# %%
npm = pandas.read_csv('../ontology/wd_npm_packages.csv')
pip = pandas.read_csv('../ontology/wd_pip_packages.csv')

# %%
resp = requests.get(
    'https://api.snyk.io/rest/orgs/dbfeeac7-bc4f-4075-8c74-706721bdae46/projects/9311858e-9bbc-4ed4-babd-03f008f18320/sbom',
    params={'version': '2022-03-31~experimental', 'format': 'cyclonedx+json'},
    headers={'Authorization': 'token 6a0a9d61-6394-4a80-b159-0de10f288a43'}
)
sbom = resp.json()
sbom
# Out:
# {'jsonapi': {'version': '1.0'},
#  'errors': [{'status': '404',
# ...

# %%
for component in sbom['components']:
    # lowercase and strip to get rid of inconsistent formatting
    if not pip[pip['pip'].str.lower().str.strip() == component['name'].lower().strip()].empty:
        link = pip[pip['pip'].str.lower().str.strip() == component['name'].lower().strip()].iloc[0]
        print(f"Linked {component['name']} to {link.to_dict()}")
    else:
        print(f"Could not link {component['name']}")
# Out:
# Linked idna to {'item': 'http://www.wikidata.org/entity/Q107380515', 'pip': 'idna'}
# Linked sniffio to {'item': 'http://www.wikidata.org/entity/Q107380894', 'pip': 'sniffio'}
# Linked typing-extensions to {'item': 'http://www.wikidata.org/entity/Q107380511', 'pip': 'typing-extensions'}
# Linked anyio to {'item': 'http://www.wikidata.org/entity/Q107381016', 'pip': 'anyio'}
# Linked appdirs to {'item': 'http://www.wikidata.org/entity/Q107380504', 'pip': 'appdirs'}
# Linked zipp to {'item': 'http://www.wikidata.org/entity/Q107381370', 'pip': 'zipp'}
# Linked importlib-metadata to {'item': 'http://www.wikidata.org/entity/Q107370332', 'pip': 'importlib-metadata'}
# Linked argcomplete to {'item': 'http://www.wikidata.org/entity/Q107380866', 'pip': 'argcomplete'}
# Linked asgiref to {'item': 'http://www.wikidata.org/entity/Q107380670', 'pip': 'asgiref'}
# Linked attrs to {'item': 'http://www.wikidata.org/entity/Q107381199', 'pip': 'attrs'}
# ...
